# %%
import pandas as pd
import ast
import re

from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import MultiLabelBinarizer

import plotly.graph_objects as go

# %% [markdown]
# The dessi dataset can be downloaded from
# https://www.kaggle.com/datasets/sensitivedetection/dessi-dataset-for-structured-sensitive-information
# where the only the DeSSI_v2 folder is necessary

# %% [markdown]
# # Evaluation - Presidio Confusion Matrix on Dessi Data

# %% [markdown]
# Use a Presidio Confusion Matrx to find label errors for Dessi Data
# Use all Predictions of Presidio without any thresholds so that no wrong predictions are ignored

# %%
dessi_train_labels = pd.read_csv("DeSSI_v2/train_labels.csv")
dessi_train = pd.read_csv("DeSSI_v2/train.csv")

dessi_dev_labels = pd.read_csv("DeSSI_v2/dev_labels.csv")
dessi_dev = pd.read_csv("DeSSI_v2/dev.csv")

dessi_test_labels = pd.read_csv("DeSSI_v2/test_labels.csv")
dessi_test = pd.read_csv("DeSSI_v2/test.csv")

dessi_all = pd.concat([dessi_train, dessi_dev, dessi_test], axis=1)
dataset_split = ["train"] * dessi_train.shape[1] + ["validation"] * dessi_dev.shape[1] + ["test"] * dessi_test.shape[1]
dataset_split_df = pd.DataFrame(dataset_split).T
dataset_split_df.columns = dessi_all.columns
dessi_all = pd.concat([dessi_all, dataset_split_df]).reset_index(drop=True)

dessi_all_labels = pd.concat([dessi_train_labels, dessi_dev_labels, dessi_test_labels], axis=0).reset_index(drop=True)
dataset_split_df = pd.DataFrame(dataset_split)
dataset_split_df.columns = ["split_type"]
dessi_all_labels = pd.concat([dessi_all_labels, dataset_split_df], axis=1).reset_index(drop=True)
# Out:
# C:\Users\Luca\AppData\Local\Temp\ipykernel_21968\3396044622.py:2: DtypeWarning:
#
# Columns (62,107,161,241,255,324,449,503,686,720,807,812,889,934,1073,1113,1133,1154,1158,1242,1317,1333,1394,1408,1470,1553,1577,1674,1729,1762,1872,1913,1940,2045,2131,2139,2209,2288,2404,2436,2601,2627,2663,2779,2841,2960,2994,3061,3063,3080,3129,3136,3250,3319,3439,3464,3499,3520,3596,3637,3649,3748,3778,3787,3808,3902,3907,3917,3951,4009,4034,4037,4069,4129,4210,4218,4252,4325,4359,4386,4479,4646,4649,4652,4710,4936,4939,5013,5065,5069,5348,5352,5356,5399,5476,5702,5736,5889,5962,6072,6094,6107,6140,6159,6337,6360,6383,6407,6415,6423,6507,6555,6567,6590,6593,6689,6809,6815,6920,6995,7042,7127,7163,7229,7295,7301,7319,7321,7354,7399,7403,7465,7474,7593,7594,7694,7719,7798,7872,7979,8179,8298,8308,8473,8542,8565,8568,8570,8579,8633,8662,8707,8835,8846,8859,8899,8933,9024,9084,9126,9170,9184,9198,9251,9329,9412,9505,9588,9592,9610,9652,9803,9818,9907,9908,9952,9975,10073,10099,10136,10161,10359,10369,10407,10427,10515,10589,10694,10748,10778,10787,10830,10839,10898,11026,11068,11201,11265,11326,11364,11372,11434,11475,11532,11559,11592,11618,11629,11649,11732,11770,11828,11886,11944,12014,12161,12240,12287,12385,12438,12508,12624,12673,12741,12843,12844,12897,12938,12977,13081,13099,13177,13195,13335,13373,13416,13437,13523,13621,13622,13671,13730,13746,13785,13914,14012,14048,14073,14126,14136,14140,14178,14204,14332,14507,14519,14525,14595,14614,14821,14828,14862,14920,14922,14948,15136,15151,15202,15250,15390,15401,15408,15442,15518,15640,15717,15781,15791,15811,15833,15858,15997,16055,16203,16211,16253,16254,16259,16277,16346,16418,16459,16517,16571,16644,16652,16731,16757,16769,16807,16845,16874,16880,16937,16993,17058,17116,17152,17256,17273,17280,17327,17362,17390,17472,17548,17602,17665,17678,17822,17882,17970,18032,18072,18096,18188,18245,18270,18351,18365,18428,18451,18455,18517,18529,18682,18721,18732,18738,18745) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
def read_files(method):
    train = pd.read_csv(f"../../Presidio/old_predictions/dessi_results/train/results_{method}.csv")
    val = pd.read_csv(f"../../Presidio/old_predictions/dessi_results/val/results_{method}.csv")
    test = pd.read_csv(f"../../Presidio/old_predictions/dessi_results/test/results_{method}.csv")
    return train, val, test

def concat_results(train, val, test):
    all_results = pd.concat([train, val, test], axis=1)
    dataset_split = ["train"] * dessi_train.shape[1] + ["validation"] * dessi_dev.shape[1] + ["test"] * dessi_test.shape[1]
    dataset_split_df = pd.DataFrame(dataset_split).T
    dataset_split_df.columns = all_results.columns
    return pd.concat([all_results, dataset_split_df]).reset_index(drop=True).T.reset_index(drop=True).T     #reset index and column names

results_method3_train, results_method3_val, results_method3_test = read_files("columnwise")

results_method_3_all = concat_results(results_method3_train, results_method3_val, results_method3_test)

# %% [markdown]
# The Classes of Presidio must be mapped to the classes of dessi to compare both

# %%
# Mapping dictionary
# IN_VEHICLE_REGISTRATION, IP_ADDRESS, MEDICAL_LICENSE, URL, US_BANK_NUMBER are matched to "Other_data"
CATEGORY_MAP = {
    "AU_TFN": "NIN",
    "AU_MEDICARE": "NIN",
    "IN_AADHAAR": "NIN",
    "IN_PAN": "NIN",
    "IN_PASSPORT": "Passport",
    "UK_NHS": "NIN",
    "US_ITIN": "NIN",
    "US_SSN": "NIN",
    "AU_ABN": "Organization",
    "AU_ACN": "Organization",
    "CREDIT_CARD": "CCN",
    "DATE_TIME": "Date",
    "shared DATE_TIME": "Date",
    "EMAIL_ADDRESS": "Email",
    "IBAN_CODE": "IBAN",
    "LOCATION": ["Geolocation", "Address", "GPE"],
    "shared LOCATION": ["Geolocation", "Address", "GPE"],
    "NRP": ["Nationality", "Religion"],  
    "shared NRP": ["Nationality", "Religion"],
    "PERSON": "Person",
    "shared PERSON": "Person",
    "PHONE_NUMBER": "Phone_number",
    "shared PHONE_NUMBER": "Phone_number",
    "US_DRIVER_LICENSE": "ID_Card",
    "shared US_DRIVER_LICENSE": "ID_Card",
    "US_PASSPORT": "Passport",
    "shared IN_PAN": "NIN",
}

# %%
def get_categories(strings):
    if strings == []:
        return ["Other_data"]
    results = []
    for s in strings:
        category = CATEGORY_MAP.get(s, "Other_data")
        if isinstance(category, list):
            results.extend(category) 
        else:
            results.append(category)  
    return results

def convert_labels(label_str):
    return [label.strip() for label in label_str.replace('{', '').replace('}', '').replace("'", "").split(',')]

def build_dataframe(results_df, threshold_score, threshold_count):
    height, width = results_df.shape
    results_copy = results_df.copy()
    print(f"Threshold score: {threshold_score}\nThreshold count: {threshold_count}")
    empty_row1 = [[] for _ in range(width)]
    empty_row2 = [[] for _ in range(width)]
    empty_row3 = [[] for _ in range(width)]
    results_copy.loc[height] = empty_row1.copy()
    results_copy.loc[height+1] = empty_row2.copy()
    results_copy.loc[height+2] = empty_row3.copy()
    for i in range(width):
        series = pd.Series([item for sublist in results_copy.iloc[2:height:2, i]
                        for item in ast.literal_eval(sublist)], dtype="object").value_counts()
        for a, b in series.items():
            if b > threshold_count:
                results_copy.iloc[height, i].append(a)
                results_copy.iloc[height+1, i].append(b)
    for i in range(width):
        entities = [re.sub(r'_\d+(\.\d+)?$', '', item)
                    for item in results_copy.iloc[height, i] if float(re.search(r'(\d+\.\d+)', item).group(1)) >= threshold_score]
        mapped_entities = get_categories(entities)
        results_copy.iloc[height+2, i] = str(set(mapped_entities))

    results_copy.loc[0] = results_copy.loc[0].apply(convert_labels)
    results_copy.loc[height+2] = results_copy.loc[height+2].apply(convert_labels)
    return results_copy

def compute_performance(results, confusion = False):
    results_copy = results.copy()
    mlb = MultiLabelBinarizer()
    y_true = mlb.fit_transform(results_copy.loc[0])
    y_pred = mlb.transform(results_copy.loc[results_copy.shape[0]-1])
    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None, zero_division=True)
    f1_micro = f1_score(y_true, y_pred, average='micro')
    f1_macro = f1_score(y_true, y_pred, average='macro')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')
    evaluation = pd.DataFrame({
        'Class': mlb.classes_,
        'P': precision,
        'R': recall,
        'F1': f1,
        'S': support
    }).sort_values("S", ascending=False).reset_index(drop=True)
    print(f'Micro F1 Score: {f1_micro:.4f}')
    print(f'Macro F1 Score: {f1_macro:.4f}')
    print(f'Weighted F1 Score: {f1_weighted:.4f}')
    
    if confusion == True:
        y_true_df = pd.DataFrame(y_true)
        y_pred_df = pd.DataFrame(y_pred)

        confusion_matrix = []
        for i in range(20):
            pred_true_compare = y_pred_df.loc[y_pred_df.index.isin(y_true_df.loc[y_true_df[i] == 1].index)]
            arr_label = []
            for j in range(20):
                val = pred_true_compare.loc[:, j].value_counts(normalize=True).get(1)
                arr_label.append(val.item() if val != None else 0)
            confusion_matrix.append(arr_label)
        fig = go.Figure(go.Heatmap(z=confusion_matrix, x=mlb.classes_, y=mlb.classes_, colorscale='Blues'))
        fig.update_layout(title_text='Confusion Matrix', height=800, width=800)
        fig.update_xaxes(title="Predicted Label")
        fig.update_yaxes(title="True Label")
        fig.show()
    return evaluation

# %% [markdown]
# # Analyze Presidio Confusion Matrix Part 2

# %% [markdown]
# Get a confusion matrix without thresholds to compare all Presidio predictions with the real labels
# Try to find label errors in Dessi
# Use columnwise approach as it is similar to CASSED approach and all three approaches perform similar for no thresholds so the approach does not matter

# %%
results_method3_thresholds = build_dataframe(results_method_3_all, 0, 0)
evaluation_method3 = compute_performance(results_method3_thresholds, confusion = True) # Best threshold_score and threshold_count

print(evaluation_method3)
# Out:
# Threshold score: 0
# Threshold count: 0
# Micro F1 Score: 0.2469
# Macro F1 Score: 0.2354
# Weighted F1 Score: 0.3321
#            Class         P         R        F1     S
# 0     Other_data  0.137213  0.242951  0.175377  6561
# 1   Phone_number  0.377567  0.990493  0.546727  4418
# 2        Address  0.169818  0.843240  0.282704  3802
# 3         Person  0.204139  0.999721  0.339046  3582
# 4            NIN  0.219195  0.651773  0.328062  3469
# 5          Email  1.000000  0.995926  0.997959  3191
# 6           Date  0.153270  0.985622  0.265286  2782
# 7            GPE  0.104825  0.911142  0.188020  2172
# 8   Organization  0.001077  0.001445  0.001234  2076
# 9    Geolocation  0.035701  0.327502  0.064384  2058
# 10     SWIFT/BIC  1.000000  0.000000  0.000000   240
# 11          IBAN  0.892019  0.892019  0.892019   213
# 12           CCN  0.345098  0.807339  0.483516   109
# 13      Passport  0.046512  0.388889  0.083086   108
# 14        Gender  1.000000  0.000000  0.000000    94
# 15      Religion  0.012819  1.000000  0.025313    93
# 16     Sexuality  1.000000  0.000000  0.000000    92
# 17   Nationality  0.012543  1.000000  0.024775    91
# 18       ID_Card  0.005207  1.000000  0.010360    68
# 19          Race  1.000000  0.000000  0.000000    58

# %% [markdown]
# The classes gender, organization, Race, SWIFT/BIC and sexuality can't be predicted by Presidio, as a result P/R/F1 is zero for these classes

# %% [markdown]
# Analyse Presidio mistakes
# First focus on the false negatives for every class, so look at the predictions which predicted other classes than the actual groundtruth

# %%
dessi_labels_cleaned =pd.read_csv("dessi_cleaned/all_labels_cleaned.csv")
wrong_columns = list(pd.read_csv("dessi_cleaned/wrong_columns.csv")["0"])

# %%
def analyse_class(class_label, focus="false negatives"):
    reduced_columns = results_method3_thresholds.iloc[:,dessi_all_labels.loc[dessi_all_labels["label"].str.contains(class_label)].index].T
    indi = []
    if focus == "false negatives":
        for i, a in zip(reduced_columns.index, reduced_columns[204]):
            if class_label not in a:
                indi.append(i)
    elif focus == "true positives":
        for i, a in zip(reduced_columns.index, reduced_columns[204]):
            if class_label in a:
                indi.append(i)
    else:
        raise ValueError("Focus should be either 'false negatives' or 'true positives'")
    d = dessi_all.iloc[:,[int(a) for a in reduced_columns.T[indi].columns.values]]
    add_info = reduced_columns.T[indi].iloc[[0,204],:]
    add_info.columns = d.columns
    df = pd.concat([add_info, d]).reset_index(drop=True)
    return df

# %% [markdown]
# analyse class gibt standardmäßig die false negatives aus
# first row display the groundtruth label and the second row of the dataframe the predictions, the other rows are the column values

# %%
df_geo = analyse_class("Geolocation")
df_geo.head()
# Out:
#       switching_center_lat                            lat  \
# 0            [Geolocation]                  [Geolocation]
# 1  [Phone_number, ID_Card]  [Date, Phone_number, ID_Card]
# 2                27.996344                      28.504554
# 3                -74.61295                      28.439854
# 4               -74.766877                     -74.618583
#
#                                      lng                   geo_latitude  \
# 0                          [Geolocation]                  [Geolocation]
# 1  [Date, Phone_number, ID_Card, Person]  [Date, Phone_number, ID_Card]
# 2                  39.3520555, -16.36384         39.3348093,-74.5492412
# 3                28.9255692, -74.5684209         39.3829683,-15.4114031
# 4                39.1601016, -16.4731214         28.1896586,-75.0695624
#
#                      lat.1              call_location_lat  \
# 0            [Geolocation]                  [Geolocation]
# 1  [Phone_number, ID_Card]  [Date, Phone_number, ID_Card]
# 2               -15.573179                      27.917121
# 3                -16.31804                     -75.027028
# 4                28.653639                      28.127593
#
#                   latitude                  geo_longitude  \
# 0            [Geolocation]                  [Geolocation]
# 1  [Phone_number, ID_Card]  [Date, Phone_number, ID_Card]
# 2                38.963465        28.1069604, -15.4784977
# 3                39.390552        39.0730144, -75.2945396
# 4               -74.929024        39.3265654, -74.6814196
#
#                call_location_lng                     mvgdxwhvwzsg  ...  \
# 0                  [Geolocation]                    [Geolocation]  ...
# 1  [Date, Phone_number, ID_Card]  [Phone_number, ID_Card, Person]  ...
# 2                     -74.572777                       -74.789275  ...
# 3                     -75.248239                        39.334576  ...
# 4                      39.447195                        39.550524  ...
#
#                        latitude.16                  long.19  \
# 0                    [Geolocation]            [Geolocation]
# 1  [Phone_number, ID_Card, Person]  [Phone_number, ID_Card]
# 2                        -15.46146               -15.381301
# 3                        28.460881                28.116343
# 4                       -16.416828               -74.729989
#
#                          long.20               geo_lat.17  \
# 0                  [Geolocation]            [Geolocation]
# 1  [Date, Phone_number, ID_Card]  [Phone_number, ID_Card]
# 2         28.3902183,-74.6056514  39.5237827; -16.6775098
# 3         28.4358689,-16.2554518  39.1538267; -16.5459905
# 4         39.4455182,-74.5375321  28.1520454; -74.6308732
#
#                     hzrgwloswcvs                         lat.56  \
# 0                  [Geolocation]                  [Geolocation]
# 1  [Date, Phone_number, ID_Card]  [Date, Phone_number, ID_Card]
# 2                     -16.323926                      39.499909
# 3                      28.278912                     -16.378117
# 4                     -15.507524                     -74.549241
#
#              call_location_lng.8               geo_lon.17  \
# 0                  [Geolocation]            [Geolocation]
# 1  [Date, Phone_number, ID_Card]  [Phone_number, ID_Card]
# 2                     -16.299797               -14.103708
# 3                     -17.884363               -15.509731
# 4                      39.447195               -74.438212
#
#                     zvneublxkuwy                latdeg.12
# 0                  [Geolocation]            [Geolocation]
# 1  [Date, Phone_number, ID_Card]  [Phone_number, ID_Card]
# 2                      -16.76674  28.0778679; -74.6895013
# 3                      39.441366   39.1035643; -17.780067
# 4                     -74.609143  39.2429523; -74.7195401
#
# [5 rows x 1384 columns]

# %%
df_geo = analyse_class("Geolocation", focus = "true positives")
df_geo.head()
# Out:
#                                                  lon  \
# 0                                      [Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                             39.4387199;-74.5492412
# 3                             39.4536535;-74.8164334
# 4                             28.3839587;-17.2639769
#
#                                         jqfyjomipilf  \
# 0                             [Address, Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                                        -74.8062027
# 3  Grand Avenue rd. on number 84 in Manchester, N...
# 4                                         39.2429523
#
#                                              country  \
# 0                             [Address, Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                                         27.7753042
# 3                         Marsvägen, Kalmar, Sverige
# 4  Warren Avenue rd. on number 235 in Ingrams Cor...
#
#                                       address_line_2  \
# 0                             [Address, Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                                         28.3718565
# 3  Nicoll Street, Washingtonville, United States ...
# 4    England Road, Hampton, United States of America
#
#                                               region  \
# 0                             [Address, Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                                        -74.5623918
# 3  Jerzego Malchera rd. on number 16C in Rybnik, ...
# 4  Źródlana 11, Zielona Góra 65-129, województwo ...
#
#                                                lat.2  \
# 0                             [Geolocation, Address]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                 Via Monte Grappa, Limbiate, Italia
# 3                                         38.9801188
# 4                    Main Street, Catskill, New York
#
#                                         ynhvrpjtcrgr  \
# 0                                      [Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                             39.3424993;-16.3189551
# 3                             39.0681271;-15.6741892
# 4                              39.333139;-16.7626164
#
#                                              address  \
# 0                             [Address, Geolocation]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                        -15.6565639
# 3                Sunnanvinden, Kristinehamn, Sverige
# 4  6 Burwell Street, Saylesville, Rhode Island 02...
#
#                                            country.2  \
# 0                             [Address, Geolocation]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                        -15.6718676
# 3  7 Goldthwaite Road, Worcester, Massachusetts 0...
# 4  Via del Pettirosso, San Giovanni in Marignano,...
#
#                                         qrzebytxdplq  ...  \
# 0                                      [Geolocation]  ...
# 1  [GPE, Geolocation, Address, Phone_number, Date...  ...
# 2                            28.3379563, -17.9135216  ...
# 3                            38.9979279, -75.2291552  ...
# 4                            27.8471096, -17.7728009  ...
#
#                                         fyzdqbiaoyos  \
# 0                             [Geolocation, Address]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2  Crossroad Road rd. on number 186 in Waterbury,...
# 3                                         38.9775039
# 4                Viale dell'Appennino, Forlì, Italia
#
#                                         hxupupwzgpyg  \
# 0                                      [Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                            28.4801805, -74.5792423
# 3                             39.372182, -74.9848918
# 4                            39.1538267, -74.8838924
#
#                                         feapxnqtchxx  \
# 0                             [Geolocation, Address]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2  31 Metropolitan Road Dyerville Rhode Island 02908
# 3                                        -16.3308235
# 4                                          28.143646
#
#                                               lng.19  \
# 0                                      [Geolocation]
# 1  [GPE, Geolocation, Address, Phone_number, Date...
# 2                             28.3359601,-74.8268432
# 3                             28.5534111,-75.3949294
# 4                               45.117899,-74.532659
#
#                                         tzcmejaucdkk  \
# 0                             [Geolocation, Address]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2  Michael's Way, Montville, United States of Ame...
# 3                                         39.1566903
# 4                                        -15.4614497
#
#                                           geo_lat.16  \
# 0                                      [Geolocation]
# 1  [GPE, Geolocation, Address, Phone_number, ID_C...
# 2                            28.1164633; -74.5108955
# 3                            28.4170218; -74.9602198
# 4                              39.11998; -74.5954738
#
#                                           country.32  \
# 0                             [Address, Geolocation]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2                                        -74.6086658
# 3    878 Huntingdon Drive, Niskayuna, New York 12309
# 4       Young Road, Orwell, United States of America
#
#                                            address.7  \
# 0                             [Address, Geolocation]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                         39.4896717
# 3                                          38.962682
# 4                                        -75.2103415
#
#                                         dadtysfqjbcs  \
# 0                             [Address, Geolocation]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                         28.4060052
# 3            Christie Road, Stratford, New Hampshire
# 4                                         28.1273995
#
#                                      geo_latitude.18
# 0                             [Geolocation, Address]
# 1  [GPE, Geolocation, Address, Person, Phone_numb...
# 2  Strada Frena, Marèo - Enneberg - Marebbe, Tren...
# 3                                           27.84977
# 4                                         28.1044789
#
# [5 rows x 674 columns]

# %% [markdown]
# Presidio can't really detect langitude/longitude, mostly detects them in combination to a address

# %%
df_iban = analyse_class("IBAN")
df_iban.head()
# Out:
#                                        iban number  \
# 0                                           [IBAN]
# 1  [GPE, Geolocation, Other_data, Address, Person]
# 2                             BA840416015950086704
# 3                             BA134412479279148046
# 4                             BA793135358257818493
#
#                                         mzfmlletrdxv  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                              HR8602480941051131138
# 3                              HR3922940390803749377
# 4                              HR0083485508782717426
#
#                              customer acc number.1               inoacc.1  \
# 0                                           [IBAN]                 [IBAN]
# 1  [GPE, Geolocation, Other_data, Address, Person]   [Other_data, Person]
# 2                             BA244245765067182584  HR0256373981877346240
# 3                             BA244077548359752640  HR2562675964356487682
# 4                             BA684541244572157128  HR4097109324215390551
#
#                                             inoacc.3  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                             RS35930352272499958270
# 3                             RS35166603313977225607
# 4                             RS35903128349560592269
#
#            international bank account number.1  \
# 0                                       [IBAN]
# 1  [Other_data, Religion, Nationality, Person]
# 2                        HR2140162044417652268
# 3                        HR2225242447300030633
# 4                        HR0962723147170495143
#
#                                    bank account id.2  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                             RS35932411437346641699
# 3                             RS35450532170765492229
# 4                             RS35839416621047098575
#
#                                       account iban.2  \
# 0                                             [IBAN]
# 1  [GPE, Geolocation, Other_data, Address, Person...
# 2                             RS35404420563738280187
# 3                             RS35831490430312312174
# 4                             RS35061982102003878817
#
#                                         hudczjnhmmbq  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                               BA419661968912540013
# 3                               BA708145992983975770
# 4                               BA015929984924931263
#
#                                   nalogodavac iban.4  ...  \
# 0                                             [IBAN]  ...
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...  ...
# 2                              HR9474939221177417985  ...
# 3                              HR7245635886432688891  ...
# 4                              HR9486177831953216544  ...
#
#                          customer acc number.3  \
# 0                                       [IBAN]
# 1  [Other_data, Religion, Nationality, Person]
# 2                        HR9587792497687086919
# 3                        HR4319804145214829661
# 4                        HR9776583681436715933
#
#                                        bank code.2  \
# 0                                           [IBAN]
# 1  [GPE, Geolocation, Other_data, Address, Person]
# 2                             BA857025456825660826
# 3                             BA499003281274255476
# 4                             BA573240110223674133
#
#                                        intf iban.2  \
# 0                                           [IBAN]
# 1  [GPE, Geolocation, Other_data, Address, Person]
# 2                            HR6609266195637307667
# 3                            HR7659022951318478142
# 4                            HR7026818920215687263
#
#                                               id acc  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                               BA569464057407615790
# 3                               BA455244868363390058
# 4                               BA815372306367509722
#
#                                         zfyvfwsupxeq  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                             RS35989008132187447709
# 3                             RS35031520741536477774
# 4                             RS35921084635049545827
#
#                                               iban.1  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                              HR0379616540442636669
# 3                              HR8152998813033338724
# 4                              HR3640175745526674202
#
#                                   country code  \
# 0                                       [IBAN]
# 1  [Other_data, Religion, Nationality, Person]
# 2                         BA962968814534321653
# 3                         BA371621873082454698
# 4                         BA617503422688801670
#
#                                          iban number  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                               BA417195272590809392
# 3                               BA797866003895190438
# 4                               BA503281324307804308
#
#                                         mppgaklccrne  \
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                               BA260796772999593264
# 3                               BA026533100298042167
# 4                               BA008161663787046327
#
#                                    iban check digits
# 0                                             [IBAN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                              HR8926892620805084675
# 3                              HR4909876543594850926
# 4                              HR3553857547926343664
#
# [5 rows x 23 columns]

# %%
def validate_iban(iban):
    # Remove spaces and convert to upper case
    iban = iban.replace(' ', '').upper()
    
    # Check that the IBAN length matches the country's expected length (optional but good to have)
    if len(iban) < 15 or len(iban) > 34:
        return False
    
    # Move the first four characters to the end
    rearranged_iban = iban[4:] + iban[:4]
    
    # Replace each letter in the IBAN with two digits (A=10, B=11, ..., Z=35)
    converted_iban = ''
    for char in rearranged_iban:
        if char.isdigit():
            converted_iban += char
        else:
            # Convert letters to numbers (A=10, B=11, ..., Z=35)
            converted_iban += str(ord(char) - 55)
    
    # Convert the string to an integer and check the remainder when divided by 97
    iban_int = int(converted_iban)
    return iban_int % 97 == 1

for a in df_iban.columns:
    ibans = df_iban.loc[2:-1, a].values
    for ib in ibans:
        if validate_iban(ib):
            print("The IBAN checksum is valid.")
            break

# %%
indis = []
for e, (i, t) in enumerate(zip(dessi_all.columns, dessi_all.iloc[-1,:])):
    try:
        if (i in df_iban.columns) and (t in df_iban.loc[102,i].values):
            indis.append(e)
    except:
        if (i in df_iban.columns) and (t in df_iban.loc[102,i]):
            indis.append(e)
for ind in indis:
    wrong_columns.append(ind)
    dessi_labels_cleaned.loc[ind,"label"] = "Other_data"

# %%
df_nin = analyse_class("NIN")
df_nin.head()
# Out:
#                                                phone  \
# 0                                [Phone_number, NIN]
# 1  [GPE, Geolocation, Other_data, Address, Phone_...
# 2                                        97204538169
# 3                                        91804536723
# 4                                        06294713858
#
#                       personal_identification_number  \
# 0                                              [NIN]
# 1  [Nationality, Person, Phone_number, Date, Reli...
# 2                                      ZZ 97 53 18 T
# 3                                          ZZ382558T
# 4                                      ZZ 80 48 11 T
#
#               date_employed_from                      steuer_id  \
# 0                    [NIN, Date]                          [NIN]
# 1  [Date, Phone_number, ID_Card]  [Date, Phone_number, ID_Card]
# 2                  ZZ 58 27 84 T                      ZZ053836T
# 3                      ZZ283276T                  ZZ 25 64 92 T
# 4                      ZZ059814T                  ZZ 07 99 38 T
#
#                                  steuer_id.1  \
# 0                                [NIN, Date]
# 1  [Date, Other_data, Phone_number, ID_Card]
# 2                                58310247966
# 3                                68372591041
# 4                                46238159072
#
#                                         bcgvociropcb  \
# 0                                              [NIN]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                   COCLLT23A57A214A
# 3                                   PZTLRY83H08H450J
# 4                                   HPAUAZ92L42N508E
#
#                                                 date  \
# 0                                        [Date, NIN]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                        01738654925
# 3                                            11-1974
# 4                                        86957014232
#
#                                  active_at.1  \
# 0                                [Date, NIN]
# 1  [GPE, Geolocation, Address, Person, Date]
# 2                           GODJPT12K26V595O
# 3                                   26/09/79
# 4                           OIGAEW63U22Y784I
#
#                           gfmpxkqdcrsh  \
# 0                        [NIN, Person]
# 1  [Geolocation, GPE, Address, Person]
# 2                             Ivelisse
# 3                     PBGETK71V00I631Y
# 4                     JXTIOT06E93Q850N
#
#                                         pinedgngccdq  ...  \
# 0                                      [NIN, Person]  ...
# 1  [GPE, Nationality, Geolocation, Address, Perso...  ...
# 2                             Jamiya Mcknight Hussey  ...
# 3                                        ZZ 483355 T  ...
# 4                                        ZZ 555608 T  ...
#
#                                         swrvxibtxbkm  \
# 0                                              [NIN]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                   NLYLBL51B55K102U
# 3                                   KMPBNA36H64T060G
# 4                                   RREWJF63Y77B340F
#
#                                         begujibmyytb  \
# 0                                       [NIN, Email]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                                   KSMZRG58R16T776Y
# 3                                   RIHWXV49E49L513D
# 4                                   CGYHHS91Y73F919D
#
#                      national_identity_card_number.4  \
# 0                                              [NIN]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                   SKBYYE80R28G171F
# 3                                   QSARZV72P02C629X
# 4                                   BQUAKN64V24I412G
#
#                                         aoithawxipeb  \
# 0                                        [NIN, Date]
# 1  [Organization, Other_data, Person, Phone_numbe...
# 2                                  August 29th, 1984
# 3                                        86034127953
# 4                                        17592304680
#
#                                         unxpsmjwhyip  \
# 0                                      [Person, NIN]
# 1  [GPE, Organization, Geolocation, Other_data, A...
# 2                                        29846703519
# 3                     Tiffany Evan Clemmons Southard
# 4                                        04269138578
#
#                                    identity_number.5  \
# 0                                              [NIN]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                   QWSKHV04E72X618Q
# 3                                   GEOJXI07Y56P651D
# 4                                   JIOEOR41Q19D538S
#
#                                         vetczbhpmiwk  \
# 0                                        [NIN, Date]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                              01-75
# 3                                        92317456082
# 4                                              11-02
#
#                                         nwkzyulosmgd  \
# 0                                              [NIN]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                        36954278108
# 3                                        35621807499
# 4                                        74530186924
#
#                           personal_numerical_code.12  \
# 0                                              [NIN]
# 1  [Nationality, Phone_number, Date, Religion, ID...
# 2                                      ZZ 55 65 56 T
# 3                                        ZZ 481385 T
# 4                                        ZZ 073649 T
#
#                     ztyhgaddzlun
# 0                          [NIN]
# 1  [Date, Phone_number, ID_Card]
# 2                    ZZ 827141 T
# 3                    ZZ 709233 T
# 4                      ZZ641479T
#
# [5 rows x 1208 columns]

# %%
df_nin = analyse_class("NIN", focus="true positives")
df_nin.head()
# Out:
#                               vcqcujsmuukw               kdxrpomztopy  \
# 0                                    [NIN]                      [NIN]
# 1  [Date, Phone_number, NIN, Organization]  [Phone_number, Date, NIN]
# 2                              280 344 565                464-24-9836
# 3                              283 560 449                229-54-2084
# 4                              022 534 739                442-71-7382
#
#                                                  ssn  \
# 0                                              [NIN]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                        50264871399
# 3                                        68739540210
# 4                                        49813706255
#
#                 ukofatwbaafw  \
# 0                [Date, NIN]
# 1  [Phone_number, Date, NIN]
# 2                045-05-6709
# 3                     Apr 16
# 4                      Mar 1
#
#                            uniquemastercitizennumber  \
# 0                                       [NIN, Email]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                          emilietemi58@jakopec.info
# 3                                   NWZRNL67G51G474E
# 4                                   XBNNFS98F68O668D
#
#                              uniform_civil_number  \
# 0                                           [NIN]
# 1  [Other_data, Phone_number, Date, ID_Card, NIN]
# 2                                     96024785313
# 3                                     83547201693
# 4                                     84765913029
#
#                                         sdnasqkqptur  \
# 0                                [Phone_number, NIN]
# 1  [GPE, Geolocation, Other_data, Address, Passpo...
# 2                                        62479510384
# 3                                    (084) 1064 7593
# 4                                        14724802683
#
#                               yshbksmmuokv  \
# 0                                    [NIN]
# 1  [Date, Phone_number, NIN, Organization]
# 2                              184 380 269
# 3                              177 132 032
# 4                              142 776 608
#
#                                        contact_email  \
# 0                                       [Email, NIN]
# 1  [GPE, Geolocation, Other_data, Address, Person...
# 2                                   SEVHCX88V88T507S
# 3                                     k.b@campos.com
# 4                           dora-sobol@lisica.com.hr
#
#                                         kugzndtesrqe  ...  \
# 0                                      [Person, NIN]  ...
# 1  [GPE, Organization, Geolocation, Address, Pers...  ...
# 2                                        522 573 302  ...
# 3                                           Arellano  ...
# 4                                        403 813 819  ...
#
#                          national_insurance_number.5  \
# 0                                       [NIN, Email]
# 1  [Organization, Other_data, Email, Phone_number...
# 2                                h.g@smith-green.xyz
# 3                                        93761250481
# 4                                        94832105679
#
#                         order_date.5  \
# 0                        [Date, NIN]
# 1  [Phone_number, Date, Person, NIN]
# 2                        206-28-3337
# 3                             16 Jul
# 4                             23 Aug
#
#                                         mqrhgooelamb  \
# 0                                [NIN, Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                     30 18 079 8035
# 3                                      +233549869575
# 4                                         7619717029
#
#                                             pager.28  \
# 0                                [Phone_number, NIN]
# 1  [GPE, Geolocation, Other_data, Address, CCN, P...
# 2                                        13748569023
# 3                                 +1 (686) 168 09 49
# 4                                    +14-91-981-6952
#
#                 drkayupmddmt  \
# 0                      [NIN]
# 1  [Phone_number, Date, NIN]
# 2                185-67-7497
# 3                558-85-3611
# 4                068-50-7385
#
#                           personal_identity_number.7  \
# 0                                              [NIN]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                        56174298035
# 3                                        86152973401
# 4                                        38905647124
#
#                           personal_identity_number.8  \
# 0                                       [Email, NIN]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                                   XKIOEC08P73W459G
# 3                                   c-b459@gmail.com
# 4                     sebastian-zou10@franklin.store
#
#                    personal_identification_number.10  \
# 0                                       [NIN, Email]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                       emma-mehta@white-mcgrath.net
# 3                                        86179025430
# 4                                        21370465988
#
#                                      personal_code.6  \
# 0                                      [NIN, Person]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                      Ahmir Adriel Najera Masterson
# 3                                        94387065210
# 4                                    Carissa Devries
#
#                 octslrhsuimb
# 0                      [NIN]
# 1  [Phone_number, Date, NIN]
# 2                111-72-1709
# 3                477-19-4481
# 4                091-76-3908
#
# [5 rows x 2261 columns]

# %% [markdown]
# Can't detect specific NINs

# %%
df_pass = analyse_class("Passport")
df_pass.head()
# Out:
#                                 verification details  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Date,...
# 2                                           W1682102
# 3                                           A1317864
# 4                                           O1382027
#
#                                    xgyrseezxpfr  \
# 0                                    [Passport]
# 1  [GPE, Geolocation, Address, Person, ID_Card]
# 2                                      O5018656
# 3                                       K418723
# 4                                      O4600267
#
#                                             passport  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                           D3319512
# 3                                           S0950263
# 4                                           H2570127
#
#                                     idp  \
# 0                            [Passport]
# 1  [Address, GPE, ID_Card, Geolocation]
# 2                              D4762856
# 3                              E4277924
# 4                              A9154282
#
#                                     british passport  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                                            1183831
# 3                                            9328368
# 4                                           97072359
#
#                             hr passport  \
# 0                            [Passport]
# 1  [Address, GPE, ID_Card, Geolocation]
# 2                              U3609154
# 3                              W6922708
# 4                              W0476146
#
#                                    dueufvgzbbix  \
# 0                                    [Passport]
# 1  [GPE, Geolocation, Address, Person, ID_Card]
# 2                                      W2582465
# 3                                      O9491883
# 4                                       N015883
#
#                    passport_identification_no       cli pspt num  \
# 0                                  [Passport]         [Passport]
# 1  [GPE, Geolocation, Address, Date, ID_Card]  [ID_Card, Person]
# 2                                    T9665447           O0829812
# 3                                    E5160766           O1711133
# 4                                    E8877814           W7511940
#
#                                psptno.1  ...  \
# 0                            [Passport]  ...
# 1  [Address, GPE, ID_Card, Geolocation]  ...
# 2                              W2072094  ...
# 3                              A7806146  ...
# 4                               F684196  ...
#
#                                    unnueytrwbkb  \
# 0                                    [Passport]
# 1  [GPE, Geolocation, Address, Person, ID_Card]
# 2                                      W6093143
# 3                                      U5507247
# 4                                      W6177201
#
#                                          visa number  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                           MD444262
# 3                                           MN145334
# 4                                           AK197984
#
#                                         wpuawkihjvgg  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                           W3924781
# 3                                           X8632888
# 4                                           G4652166
#
#                                          mk pspt num  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                           KS260799
# 3                                           NT847970
# 4                                           EF683072
#
#                                  guosouvxdqwr  \
# 0                                  [Passport]
# 1  [GPE, Geolocation, Address, Date, ID_Card]
# 2                                    W5630895
# 3                                    O2237222
# 4                                    U4024894
#
#                                    xpsosvqziict  \
# 0                                    [Passport]
# 1  [GPE, Geolocation, Address, Person, ID_Card]
# 2                                       N090850
# 3                                      W6453894
# 4                                      W5198503
#
#                                    customer passport  \
# 0                                         [Passport]
# 1  [GPE, Geolocation, Address, Person, Date, ID_C...
# 2                                           U7717741
# 3                                           A9314129
# 4                                           A4783794
#
#                                   uk passport number  \
# 0                                         [Passport]
# 1  [GPE, Geolocation, Other_data, Address, Phone_...
# 2                                           60243679
# 3                                           51140705
# 4                                           72453327
#
#                       identification_number_passport  \
# 0                                         [Passport]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                           W8766944
# 3                                           T2632733
# 4                                           H2038703
#
#                                          psptid
# 0                                    [Passport]
# 1  [GPE, Geolocation, Address, Person, ID_Card]
# 2                                      U6108611
# 3                                      K5779386
# 4                                      T2528310
#
# [5 rows x 66 columns]

# %% [markdown]
# Presidio can only detect US Passports

# %%
df_per = analyse_class("Person")
df_per.head()
# Out:
#                                         zhiiickzngbe
# 0                                      [Person, NIN]
# 1  [Organization, Other_data, Phone_number, Date,...
# 2                                        37519064825
# 3                                        86705213492
# 4                                         3452918671

# %%
df_per.values
# Out:
# array([[list(['Person', 'NIN'])],
#        [list(['Organization', 'Other_data', 'Phone_number', 'Date', 'ID_Card', 'NIN'])],
#        [37519064825],
#        [86705213492],
#        [3452918671],
#        [26904385719],
#        [16795830420],
#        [48021379563],
#        [24896350710],
#        [43806792516],
#        [80497251366],
#        [68079415231],
#        [51293860478],
#        [91374860526],
#        [26781390545],
#        [29318570649],
#        [30762154980],
#        [15492736087],
#        [67052843914],
#        [53978041621],
#        [69102843757],
#        [58632407198],
#        [80961374520],
#        [32496185074],
#        [38109245764],
#        [6372418951],
#        [34725981602],
#        [24631975803],
#        [84971035625],
#        [90534678124],
#        [97834216506],
#        [97453026814],
#        [63720948513],
#        [7498152367],
#        [56037189240],
#        [45632798102],
#        [32678590147],
#        [49037285168],
#        [91826504733],
#        [7192543683],
#        [63815490723],
#        [38672401597],
#        [65781390249],
#        [90456213872],
#        [35674902815],
#        [38694520172],
#        [70683529410],
#        [34879102655],
#        [10354876925],
#        [72638504195],
#        [85316427095],
#        [37164580292],
#        [30148625970],
#        [75241608390],
#        [86421597300],
#        [49286701534],
#        [31456027980],
#        [35798201647],
#        [7935841626],
#        [95760132485],
#        [62470815399],
#        [43821956701],
#        [2758936148],
#        [39075641825],
#        [16480932577],
#        [65234807913],
#        [47390286158],
#        [40763928515],
#        [13720456980],
#        [3426987157],
#        [7952846312],
#        [4953217867],
#        [14823956070],
#        [38461795028],
#        [87406912351],
#        [60715839240],
#        [90625341876],
#        [47891260355],
#        [61937420589],
#        [85214673904],
#        [79581263409],
#        [31480275694],
#        [73549801266],
#        [4327516984],
#        [39654182079],
#        [65397248101],
#        [96410725833],
#        [72360845916],
#        [37481296054],
#        [21849603755],
#        [9627514832],
#        [67801324956],
#        [64751392088],
#        [39521804671],
#        [45639718028],
#        [36170452985],
#        [62493017851],
#        [82675901346],
#        [51982670438],
#        [83052946174],
#        [5976418238],
#        [9348156273],
#        ['validation']], dtype=object)

# %%
indis = []
for e, (i, t) in enumerate(zip(dessi_all.columns, dessi_all.iloc[-1,:])):
    try:
        if (i == "zhiiickzngbe") and (t in df_per.loc[102,i].values):
            indis.append(e)
    except:
        if (i in "zhiiickzngbe") and (t in df_per.loc[102,i]):
            indis.append(e)
for ind in indis:
    wrong_columns.append(ind)
    dessi_labels_cleaned.loc[ind,"label"] = "NIN"
indis
# Out:
# [24764]

# %%
df_pho = analyse_class("Phone_number")
df_pho.head()
# Out:
#                        rdmbvarvwvjz  \
# 0                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]
# 2                      445314460907
# 3                      440544560923
# 4                      444534460923
#
#                                     emailpromotion.6  \
# 0                              [Phone_number, Email]
# 1  [GPE, Nationality, Geolocation, Other_data, Ad...
# 2                             cmiller2044@aguilar.ly
# 3                            bharman@martinez.online
# 4                                dvladusic@gmail.com
#
#                                          telephone.5  \
# 0                                     [Phone_number]
# 1  [Organization, Other_data, Passport, Date, ID_...
# 2                                          243048296
# 3                                          243841266
# 4                                          241699147
#
#                           phone_no.4  \
# 0                     [Phone_number]
# 1  [Address, GPE, Date, Geolocation]
# 2                       4O0229532323
# 3                       1O8044576295
# 4                       8O2077646592
#
#                                      phone_number.15  \
# 0                                     [Phone_number]
# 1  [Organization, Other_data, Passport, Date, ID_...
# 2                                          557522686
# 3                                          557396579
# 4                                          553231611
#
#                        zhignxkecbng              cell_phone_number.16  \
# 0                    [Phone_number]                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]  [Date, Other_data, ID_Card, NIN]
# 2                      233281895900                      447700900543
# 3                      233283671760                      447700900636
# 4                      233286135584                      447700900546
#
#                        zfjoaqmkqfem               cellphone_number.23  \
# 0                    [Phone_number]                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]  [Date, Other_data, ID_Card, NIN]
# 2                      447700900081                      233555144749
# 3                      447700900829                      233557989303
# 4                      447700900967                      233558106237
#
#                              sms.32  ...  \
# 0                    [Phone_number]  ...
# 1  [Date, Other_data, ID_Card, NIN]  ...
# 2                      233541752803  ...
# 3                      233547322019  ...
# 4                      233547151949  ...
#
#                                          phone_ext.5  \
# 0                                     [Phone_number]
# 1  [GPE, Organization, Geolocation, Other_data, A...
# 2                                          500351531
# 3                                          503336796
# 4                                          509905084
#
#                mobilephonenumber.15                 family_contact.13  \
# 0                    [Phone_number]                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]  [Date, Other_data, ID_Card, NIN]
# 2                      233551456861                      233279471352
# 3                      233557909482                      233274084351
# 4                      233552491728                      233277175792
#
#                                         telephone.34  \
# 0                                     [Phone_number]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                    +234 1 012 6009
# 3                                    +234 1 662 3967
# 4                                    +234 1 525 7813
#
#                              family_contact_email.24  \
# 0                                [Phone_number, NIN]
# 1  [GPE, Nationality, Geolocation, Address, Perso...
# 2                                   SVMYQX46D36U367M
# 3                                   IZUDDQ97L62I775S
# 4                                   FCZRWN55W26S618S
#
#                        dohocumdqdlz  \
# 0                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]
# 2                      233260449189
# 3                      233266458589
# 4                      233266021864
#
#                                         kbakskboyent  \
# 0                                     [Phone_number]
# 1  [Organization, Other_data, Passport, Date, ID_...
# 2                                          546075770
# 3                                          541816952
# 4                                          549924762
#
#                                         hzxgmsuvjjav  \
# 0                                     [Phone_number]
# 1  [Organization, Other_data, Passport, Date, ID_...
# 2                                          270734431
# 3                                          276131641
# 4                                          279367956
#
#                        gwfoopuknpio                      ukhxzgzxwdgx
# 0                    [Phone_number]                    [Phone_number]
# 1  [Date, Other_data, ID_Card, NIN]  [Date, Other_data, ID_Card, NIN]
# 2                      440444760765                      233282697405
# 3                      441054660784                      233284078101
# 4                      448624860123                      233285618272
#
# [5 rows x 42 columns]

# %%
for i in ["emailpromotion.6", "phone_no.4", "jbubejnymgfj", "email.96", "immrqliobmwo", "family_contact_email.24"]:
    print(df_pho[i].values)
# Out:
# [list(['Phone_number', 'Email'])
#  list(['GPE', 'Nationality', 'Geolocation', 'Other_data', 'Address', 'Person', 'Email', 'Date', 'Religion', 'ID_Card', 'NIN'])
#  'cmiller2044@aguilar.ly' 'bharman@martinez.online' 'dvladusic@gmail.com'
#  'kalipalmer874@krause-howe.org' 'pia.stoiljkovic87@yahoo.hr'
#  'joshua-whelan@dunn.com' 'everetteharkins@green.info' 'a-j456@yahoo.com'
#  'h.seaman877@hotmail.com' 'h.higgins301@hall-hughes.net'
#  'ivicabosiljevac@hotmail.com' 'm.w@preston-anderson.org' 'ac@yahoo.com'
#  'ah@jensen-green.us' 'nf@gmail.com' 'e.b@gmail.com'
#  'n-a9@mcknight-butler.online' 'r.r4635@green.biz'
#  'lex.lemons@hotmail.com' 'm-rash@curry-williams.site'
#  'j.roberts@hotmail.com' 'p-jones22@wood.xyz' 'mhowell5457@dawson.xyz'
#  'zjordan735@patton-roberts.biz' 'm-ranic3@inet.hr' 'iva-dimic@zagreb.hr'
#  'carolinemartinez@clay-thomas.info' 'v.p@gmail.com'
#  'kimberlyray743@gmail.com' 'charlottehoffman@gmail.com'
#  'jayla-martinez@brewer-harris.us' 'mw@hotmail.com'
#  'z-licul9067@gmail.com' 'lstewart@nguyen.store' 'l.tolic8@zg.t-com.hr'
#  'melanie.oliver@white.xyz' 'vinkoparada5@muscet.org'
#  'kkerum1@zakinja.org' 'f-coggins9694@shepherd-daniel.com'
#  'w-t8575@mcknight-harris.website' 's-buchanan@gmail.com'
#  'nwhitehead@hurley.co' 'n-p96@zg.t-com.hr' 'charlescrandall387@gmail.com'
#  'agarcia1016@white-simmons.biz' 'b-k@nizetic.net'
#  'a-walker@oneill-atkinson.biz' 'd.d@lee.ly' 'm-s1@buljan.biz'
#  'j.vickovic@lovric.com' 'fwilson4993@johnson.biz' 'nicollasic@inet.hr'
#  'philip-hill@miller-gonzales.org' 'd-e35@gmail.com' 'bkralj97@maretic.hr'
#  'katerina-magana38@nguyen-contreras.biz' 'amir.walker@gmail.com'
#  'carsen-desantis@harper.us' 'kinzley-soto@torres.org' 'b.l23@hotmail.com'
#  'monikavukojevic@globalnet.hr' 'd.p@zg.t-com.hr' 'mw@smith.website'
#  'a.h@yahoo.hr' 'zorkasculac4719@valjetic.com' 'i.ivanovic@poljak.org'
#  'n.t90@roberts-hampton.website' 'elena-gashi@valentic.info'
#  'csellers96@parsons.net' 'maci.winkler@blair-garcia.website'
#  'm-zhang@reyes-spencer.com' 'leiadillon@gmail.com'
#  'chloehall125@hotmail.com' 'm.l@gmail.com' 'r.o@gmail.com'
#  'j.calhoun@potter-miller.website' 'r-h@yahoo.com'
#  'a.metcalf@martin.store' 'emily.chavez5413@hotmail.com'
#  'm.piskovic6880@vuckovic.biz' 'i.ivanovic@poljak.org'
#  'c-shelton0@winters-carr.ly' 'w-t8575@mcknight-harris.website'
#  'f-a26@hotmail.com' 't.l@williams.co' 'leo-sabljak3@petrovic.hr'
#  'n.fierro@yahoo.com' 'vedranmofardin6630@stefanec.info'
#  'lydia-doyle86@wilson-gordon.xyz' 'c.martinez8@frost-ryan.org'
#  'z.s7@rakuljic.org' 'j.p@petek.info' 'violette-corley@logan.xyz'
#  'd-bravo1@butler.net' 'aking20@lee.website' 'natalie-ford@briggs.net'
#  'l-prcela4362@globalnet.hr' 'zg1191@burton-williams.us'
#  'serenitygoodman83@king-williams.store' 's-jones@wiley.com' 'train']
# [list(['Phone_number']) list(['Address', 'GPE', 'Date', 'Geolocation'])
#  '4O0229532323' '1O8044576295' '8O2077646592' '3O2396152775'
#  '8O3499207323' '0O0996370965' '4O9622970674' '1O8900657360'
#  '0O6383671180' '6O9059262899' '3O9487803275' '2O6032150783'
#  '5O0550421726' '6O0095265987' '2O8432126491' '5O1051867949'
#  '1O7660925085' '8O3051144781' '3O1342591904' '8O8863709023'
#  '8O1313833772' '2O2379279084' '5O9486090483' '6O2362077680'
#  '2O6496971361' '8O8098049360' '9O7930385352' '6O2976134949'
#  '7O9989019095' '9O3684447288' '4O7240301752' '9O3711392831'
#  '1O6840163597' '5O6950507336' '6O4823113433' '4O6828770741'
#  '6O9089310210' '4O4230229510' '6O1878160687' '5O4035355115'
#  '1O9625724110' '6O5254397727' '7O0306109504' '6O9401245465'
#  '8O9909248043' '9O2272455576' '7O2062255814' '0O2399933775'
#  '9O7449604308' '3O6578153252' '5O7387337723' '2O0425581535'
#  '0O4032503557' '8O2810279178' '5O6775943501' '7O2299130704'
#  '9O2719726700' '9O9989306763' '7O0639591103' '6O2316989430'
#  '9O4359107999' '3O9477116629' '2O2158037766' '1O7848403235'
#  '9O3104709464' '6O4454841419' '2O7425207177' '5O9528351637'
#  '3O5072109474' '8O8708322852' '0O4237484529' '7O4651033390'
#  '6O4713815937' '8O4751002779' '3O5911862040' '7O8032896832'
#  '4O2845545158' '9O4397435616' '1O8040069936' '1O9216883644'
#  '6O2161935389' '3O3136617424' '1O7323029273' '7O2888867880'
#  '1O8945278897' '3O2168028612' '0O0839931625' '6O8604487624'
#  '7O2460871064' '4O2057342654' '3O7087992670' '3O8451200883'
#  '7O6299471880' '9O7138515218' '4O2297699268' '6O9865342053'
#  '5O4150655641' '6O4057433323' '8O7758495655' '5O8112476774' 'train']
# [list(['Phone_number', 'Email'])
#  list(['GPE', 'Nationality', 'Geolocation', 'Other_data', 'Address', 'Person', 'Email', 'Religion', 'ID_Card', 'NIN'])
#  'j-p@fabijanic.com.hr' 'ap@bailey.co' 'lbarrett@yahoo.com'
#  'm.lefebvre725@holmes-cunningham.online' 'karlo-tkalec6@bozickovic.biz'
#  'helen.jones8@gonzalez.xyz' 'sara-eldic@filipovic.info'
#  'n.bogdan0@djurasevic.org' 'terezijakezerle9610@zagreb.hr'
#  'tbruic@komar.com' 'dorian-ralic@vojkovic.com' 't.d969@griffin-clark.net'
#  'z-licul9067@gmail.com' 'j.jovicic@hotmail.com' 'mjanes@yahoo.com'
#  'josecantu317@hotmail.com' 'aiden.simmons@patrick.site'
#  'duje.simic4@zg.t-com.hr' 'crodriguez@hotmail.com'
#  's.snyder@durham-oconnor.ly' 'i.djokovic3@inet.hr'
#  'e.l@hughes-williams.biz' 'bbulic@gmail.com' 'adelinecarroll7@yahoo.com'
#  'jadekeele@mueller.ly' 'n.k213@gmail.com' 'lilypotts221@henson-lee.site'
#  'j.nixon852@gmail.com' 'aleksandarbozic@raguz.org'
#  'tuckermartel@gmail.com' 'isaiahlawson20@joseph.ly'
#  'adeline.hester301@gmail.com' 'aylen-mcintyre@walker.ly'
#  'sm@burke-wilkerson.org' 'kemaribarrios@barber.site'
#  's-thomas8@yahoo.com' 'a-c6@yahoo.com' 'm.best@yahoo.com'
#  'calvin.revels@yahoo.com' 'p-f@yahoo.com' 'l.eliason44@hotmail.com'
#  'd.j@godinic.info' 'aubriella-schubert@yahoo.com'
#  'jerichocardenas190@bennett-cook.net' 'chloereed@hotmail.com'
#  'mhubbard@watts.online' 'bd60@cain.info' 'j-k47@gmail.com'
#  's.w2934@acevedo-garcia.online' 'c-ford@hensley.xyz' 'a-t106@kim.com'
#  'yh@yahoo.com' 'w-nielson64@gmail.com' 'maria-haynes680@hotmail.com'
#  'maci.winkler@blair-garcia.website' 'julian-snapp@mendez.site'
#  'o.t@zg.t-com.hr' 'marijeta.maric497@nimac.hr' 'emily.patel@conley.org'
#  'd.v@yahoo.com' 'essencesamuels@may-allison.website' 'c-pitts@gmail.com'
#  'j.t7@summers.website' 'd-hazelwood@hotmail.com' 'j-c@hotmail.com'
#  'charlotterichardson@gmail.com' 'kc@henderson-jones.site'
#  'tyce-smith0@hotmail.com' 'emmettevans89@hotmail.com'
#  'evelynhickman33@durham-allen.online' 'iizquierdo@miles-coleman.ly'
#  'm.hamilton@hotmail.com' 'w.espinoza55@hotmail.com'
#  'zoran-petak@crnkovic.info' 'ethan.jones@taylor.biz' 'b-r@dixon-adams.us'
#  'az543@zupanic.com' 'leon-thomas@berg-armstrong.online'
#  'a-g5149@drakulic.com.hr' 'l-s@smith-james.biz' 'fs741@gmail.com'
#  'macklinmace@wiley.net' 'maci.winkler@blair-garcia.website'
#  'm-cipric633@milatic.org' 'a-heffernan6128@hotmail.com'
#  'jahmari.albarran3@gardner-roberts.biz' 'a.j@lasic.info' 'i-s@yahoo.com'
#  'mathisrussell10@gmail.com' 'f.p699@xnet.hr' 'l.b@hotmail.com'
#  'a-z79@simic.com.hr' 'kinzley-soto@torres.org' 'm.o@smith-jones.com'
#  'l.sanjuan@maldonado-lynn.com' 'a-pearson@hotmail.com'
#  'nchaplin608@hotmail.com' 'j-d801@edwards-phillips.us'
#  'brooklynn.gonzalez6057@lopez-barnes.info' 'd.cukusic19@zagreb.hr'
#  'train']
# [list(['Email', 'Phone_number'])
#  list(['GPE', 'Geolocation', 'Other_data', 'Address', 'Person', 'Email', 'ID_Card', 'NIN'])
#  'jmccabe99@smith-perry.ly' 'k.c43@morales-brown.site'
#  'ericbenford1012@marshall-hatfield.us' 'e.cruz61@gmail.com'
#  'martinaribic@rubesa.org' 'l-fowler@houston-buchanan.co'
#  'ankica-vinojcic@hotmail.com' 'zj6606@hotmail.com' 'j-m48@macan.com'
#  'noafucek716@kucic.com.hr' 'jacob.piazza7269@schneider-harris.net'
#  'l-pijuk66@zagreb.hr' 'aaronmagallanes@knapp.site'
#  'k-w265@phillips-burns.ly' 'l.sanchez71@miller-taylor.biz'
#  'sp@knezovic.com' 'n.kraljevic@t.ht.hr' 'm.d4@sinozic.org'
#  'r.h11@hotmail.com' 'i-p@vip.hr' 'p.s8@net.hr' 'a.m@mardesic.biz'
#  'dusanperic3@marusic.com.hr' 'marinkos@popovic.info' 'b-s@xnet.hr'
#  'm-k@ladavac.com.hr' 'a.d@lowe.us' 'c-west@bradley-flores.site'
#  'joconnell7@henry.org' 'bria-levine@gmail.com' 'd.g@jones-flynn.online'
#  'elizabethgladden@rollins-roberts.us'
#  'jacob.mclain5393@anderson-hurst.org' 'n.k213@gmail.com'
#  'joseph-wright@cohen.biz' 'kalinguyen6@lopez-hall.net' 't-r8422@t.ht.hr'
#  'hbrittain@griffin.online' 'd-d@hotmail.com' 'sanja.matosic5@zagreb.hr'
#  'b.mulligan46@yahoo.com' 'csampson@johnson-collins.site'
#  'edwardcaruthers@perkins.site' 'g.m@west-carpenter.store'
#  'm.c@zg.t-com.hr' 'brynn.jones2802@lee.com'
#  'thomaschampion718@noble-kelley.info' 'k-b359@gonzalez-garcia.net'
#  'salembenner574@yahoo.com' 'j-hicks556@beard-fox.xyz' 'a-s393@net.hr'
#  'zdravkoberisic9@nizetic.org' 'a.koch@davis-wood.store'
#  'josiah.boulware0@peterson-mann.us' 'ps@klarin.info'
#  'n-vukanovic37@xnet.hr' 'ilagroth@yahoo.com' '29 702 24 475 55'
#  'jm7105@wilson-ali.online' 'h-montgomery4419@church-martinez.website'
#  'lucascarney617@porter-sherman.us' 'emmadavis@white-gregory.org'
#  'b.t7@bozanovic.com' 'ss487@hotmail.com' 'tc@cantrell-rodriguez.biz'
#  'a.r297@xnet.hr' 'emiliano-stewart@shields.xyz'
#  'a.leyva2639@miller.website' 'm.m70@barnes-reed.info'
#  'kylee-gingerich@wheeler-wright.com' 'lilliana.davis@sanchez-hines.store'
#  'bh5@smith-mason.us' 'k-kruse@gmail.com' 'z.k@bernardic.info'
#  'isaiah.scott3743@white-valentine.org' 'sasamarinovic99@t.ht.hr'
#  'elimatthews1767@jones-berger.co' 'leo-givens@adams-blackburn.xyz'
#  'r-carter818@harrison-sanchez.site' 'es@xnet.hr' 'j.c@young-juarez.ly'
#  'lf@marsh-eaton.online' 'j.m86@yahoo.com' 'milkakosturjak@lisica.org'
#  'dmcleod2@rose-huerta.com' 'luce.banovac74@colic.hr'
#  'jakhi.newberry3590@smith.org' 'a.baresic62@moscarda.hr'
#  'marieta.milakovic3@inet.hr' 't.landry@nichols-mosley.info'
#  'william.faria964@espinoza-shepherd.info' 'cosetteobrien@yahoo.com'
#  'a.salazar@garcia.biz' 'e-b@fitzgerald.online'
#  'e.alvarez@perez-dixon.site' 'clarahernandez@contreras-munoz.ly'
#  'gjones6@yahoo.com' 'g.l@bonilla-moran.ly' 'j.williams@phillips.website'
#  'benjaminharris@lopez.info' 'train']
# [list(['Email', 'Phone_number'])
#  list(['Other_data', 'Email', 'Date', 'ID_Card', 'NIN'])
#  'corbin.patterson915@smith-french.info' 'jacobontiveros40@hotmail.com'
#  'm.p@gmail.com' 'fionaharms2@gmail.com' 'l-martin99@yahoo.com'
#  'i.v@baric.org' 'c-perez43@schwartz.website' 'kb@pierce.site'
#  'macie-perera@johnson.site' 'a-p46@cook-khan.co' 'antunsalapic@inet.hr'
#  'm-kovacic@kovac.net' 'r-mladic9061@vip.hr' 'g-francis92@gmail.com'
#  'a.f792@hotmail.com' 'elias-sanchez7@hughes.website'
#  'gitaskopljanac5@brlek.net' 'h.frazier@gmail.com' 'czelenko48@gmail.com'
#  '01 106 0523' 'j-k@zagreb.hr' 'w-t8575@mcknight-harris.website'
#  '+67 (4) 7 47 /22 09 48 55' 'm.b8@nacinovic.org'
#  'lcurtis6855@reese-warner.ly' 'vinko.nozica2099@yahoo.com'
#  'np@beletic.com' '032.305.6555' 'c-r443@garcia.net'
#  'ethan.downs@parker-mitchell.net' 'maddilyn.cox@yahoo.com'
#  'emma-ramirez8004@moore-casey.store' 'dominic.johnson@hotmail.com'
#  'e.c@lloyd-murphy.com' 'matthew-easterling3@gmail.com'
#  'm.pointer@fernandez-sosa.ly' 'giseleclark6179@hubbard-adkins.store'
#  'n-zimmerman2@dorsey-mccoy.biz' 'xjohnson@guzman.co' 'j-keyes@gmail.com'
#  'bs@gmail.com' 'tanner-rodriguez@obrien-burns.store'
#  'javonstory@hotmail.com' 'vlado.kolar@zagreb.hr' 'taliaelrod6@taylor.net'
#  'aw@madden-anthony.net' 'b.t77@parsons-smith.store'
#  'emma.guerrero@johnson-dixon.org' 'ec1@mcclain-hart.com'
#  'clay-booker@tucker-johnston.org' 'k-f@hall.biz' 'm-r@xnet.hr'
#  'franjo-sojat44@globalnet.hr' 'd.m@martin.com'
#  'darkoveckovic1@semialjac.org' 'mc3562@gmail.com'
#  'c.vanburen3695@deleon-howard.info' '+84 (5) 4 02 /39 32 63 16'
#  'samara.tirado71@reyes-valdez.net' 'ayeh8@chapman-baker.net'
#  'amayhew25@yahoo.com' 'kenneth-an@mcdonald-anderson.ly'
#  'zborges510@palmer.biz' 'kylie.bradshaw@hotmail.com'
#  'ethan.padilla@riley-wall.info' 'w-ford5592@castro-rojas.ly'
#  'm-s94@hotmail.com' 'ar4@martin-garcia.xyz' '32471978 5965'
#  'skyla-glover6021@austin-hamilton.website' '+33 51 4226 0450'
#  'd.o2@yahoo.com' 'jw953@gmail.com' 'd-sebastian@gmail.com'
#  '(825) 7863-3110' 'e.t37@inet.hr' 'jreyes2047@perez.site'
#  'r-carter818@harrison-sanchez.site' 'tristenlyons@barnes-murphy.site'
#  'tleonard81@hotmail.com' 'acoughlin@acevedo-giles.info' '13671289377'
#  'p.klaric913@stefanec.net' '001-569-686-5266x319' 'e.cruz61@gmail.com'
#  'al@globalnet.hr' 'azirovcic@leskovic.biz' 's.cardona@hotmail.com'
#  'a-t106@kim.com' 'j-w0@hotmail.com' 'e-mcintosh@yahoo.com'
#  'ayeh8@chapman-baker.net' 'ialexander@nelson-miller.info'
#  'l.livaic@net.hr' 'cj61@martin.biz' 'benjamin-tomrecaj@vip.hr'
#  'w-r@ramirez.net' 'jason.salgado5@costa.xyz'
#  'delaney.pinkston@wyatt-lopez.ly' 'crodriguez@hotmail.com' 'train']
# [list(['Phone_number', 'NIN'])
#  list(['GPE', 'Nationality', 'Geolocation', 'Address', 'Person', 'Religion'])
#  'SVMYQX46D36U367M' 'IZUDDQ97L62I775S' 'FCZRWN55W26S618S'
#  'OSBFJU52I69B669X' 'ZCQHVX93E38W474R' 'TESRYP90S42S811K'
#  'JAQBXC65X27E110V' 'NSMCJS68T47N543K' 'DAXQDU85Y84E162Z'
#  'GBWDGK40W75S028B' 'PJEWOX69A25J636D' 'KRYHYF15O30O067H'
#  'AIZTYT12S73V784V' 'WLDMXJ43G65Q511G' 'QYKDUJ82A66C802Z'
#  'KDYQHU65L19F050K' 'XTANYR43W04F284N' 'JDDTUT66J42T417A'
#  'JYEVHS71N57X648X' 'QYWSTZ31B72H142P' 'LSHYQH61B14M204Y'
#  'KLUHQF89C95T541I' 'DUNUBN00V48N908L' 'NSDUHB18H13Q437F'
#  'SXELAN90G79F674N' 'BVTRPQ68S61X054U' 'DOSTVF27E41M730V'
#  'XZDFLN45L87T325H' 'QIFCUQ84A75B071K' 'IVFSCW58D72V008X'
#  'WSQAJH53T59W619H' 'WBNKYP96J24S346N' 'GXGTVY63J05J857A'
#  'CRNNOO30G59D275A' 'GLSGBA20B07B931N' 'WJJWPR86L88C661R'
#  'GOMXFI49Z71O159X' 'YNNFOD28F09W693U' 'MHDNNH87V50G910N'
#  'YXTVFJ01B23L387C' 'WINUWW46X27D012B' 'UMSSKZ19K78Z958K'
#  'HKLSSK58J47F344D' 'SWNHCU11W47L319O' 'OOKMNC49J37K740W'
#  'SBPREE03D99H350D' 'EJYOPJ02O83X841N' 'CLTOFY36J91D259C'
#  'ENQZNU29Q77X630X' 'SDZCXQ37C36B579E' 'EDLAIS16K65K326K'
#  'CCVMHU78I55N764R' 'LTXKQX45Q24T871H' 'EJQNVL25H84V724V'
#  'NIRLVU44J54Q137F' 'UXWMAG79P89P626D' 'CAWXMM31R63W369J'
#  'SIOPYX35I14D383D' 'HXJGLC09B09E671A' 'XRIZBP84C97M257M'
#  'LPUTVC93S32R282P' 'NRUEPK62F77T624N' 'NDIOKP88Q36Y103Z'
#  'MOTHIX38R38B251V' 'SIUZTH94P94I798Z' 'BLDLPZ71X43E465N'
#  'GGOZHE34G16G606A' 'URMCPP48G24U694L' 'BQIDIA53Z99G497L'
#  'YCTVQH54X77T188E' 'IDDKEA16X43N144M' 'HMHEVT64J95E141T'
#  'BANRNR86G92P874W' 'TWYIHA53Y77M806N' 'NBSSVX46J14R070A'
#  'LFFYWN42X38R987U' 'GSWMBT52A56Y029O' 'CTGLXT96V62W973R'
#  'ZEJVFH56C06O971O' 'FEUBIB98O90I290X' 'GPDEOP55N18V247Q'
#  'LFOHKD29O32E741M' 'IVSNHP33I82K398C' 'WIITQA08N29A049W'
#  'ZFVUEQ01X75A210H' 'GHVSFV29M91U265N' 'BRTFCD56U97U889R'
#  'FCZUMH74Q59K727A' 'HCBKJO64V94Y528N' 'FRRAXN73D33S828P'
#  'EGJIYL93G05K359S' 'LOJVDK42L15E916R' 'EEPVYQ65I88G991X'
#  'TVJDRB75N68K745X' 'SLZPKC74H53Y505J' 'RXPNLF89V52D999C'
#  'BAQJOX35T30J175E' 'QUQCUA81H43H156V' 'WXYKDE18L48S780N'
#  'GSTETF89M31Z858F' 'validation']

# %%
indis = []
cols = ["emailpromotion.6", "jbubejnymgfj", "family_contact_email.24"]
for e, (i, t) in enumerate(zip(dessi_all.columns, dessi_all.iloc[-1,:])):
    try:
        if (i in cols) and (t in df_pho.loc[102,i].values):
            indis.append(e)
    except:
        if (i in cols) and (t in df_pho.loc[102,i]):
            indis.append(e)
for ind in indis:
    wrong_columns.append(ind)
len(indis)
# Out:
# 3

# %%
dessi_labels_cleaned.loc[indis,"label"]
# Out:
# 1040     Phone_number,Email
# 7836     Phone_number,Email
# 24064      Phone_number,NIN
# Name: label, dtype: object

# %%
dessi_labels_cleaned.loc[indis[0],"label"] = "Email"
dessi_labels_cleaned.loc[indis[1],"label"] = "Email"
dessi_labels_cleaned.loc[indis[2],"label"] = "NIN"

# %%
df_pho = analyse_class("Phone_number", focus="true positives")
df_pho.head()
# Out:
#                                         fxvspjlbgrhm  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                +55 (031) 4280-4254
# 3                                    +23 (0511) 2695
# 4                                (251) 724-6950 x782
#
#                                         phone_number  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                    (071) 1428-1198
# 3                                         2576223255
# 4                                         1415554659
#
#                                             phone_no  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Person...
# 2                                       31 0020-5087
# 3                                  +55 93 99082 4085
# 4                                      +233554323182
#
#                                         family_email  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                        152691757/5
# 3                                +45 (65) 90179-6903
# 4                                        044 209 709
#
#                                         rrubbcpjrqht  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                         0209981558
# 3                                        721 0879103
# 4                                      +447700900238
#
#                                            phone_ext  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                       (470)4960902
# 3                                         2316208510
# 4                                         1602520745
#
#                                         ijfsukxdjfhd  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                    (051) 2074-9163
# 3                                   +97 (156) 935900
# 4                                         5622274934
#
#                                         bndecuspucsy  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Phone_...
# 2                                        13840749598
# 3                                   +51 61 8358 3615
# 4                                  +55 90 96141 4013
#
#                                            homephone  \
# 0                              [Email, Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Person...
# 2                                19081 0 24 14 18 94
# 3                             danica-dereta3@xnet.hr
# 4                                    s.d30@yahoo.com
#
#                                  cell_phone_number  ...  \
# 0                                   [Phone_number]  ...
# 1  [GPE, Geolocation, Address, Phone_number, Date]  ...
# 2                                 +91 6978 5766 35  ...
# 3                                 +06 3801 3028 32  ...
# 4                                 +64 1530 1149 85  ...
#
#                                 cell_phone_number.19  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                     5780/ 22 04 07
# 3                                         0288658117
# 4                                   935-837-2993x992
#
#                                         ofyzhctfwwoa  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                        021 841 629
# 3                                      +233244463951
# 4                                     03406 670 0584
#
#                                         zsjibvlwpvuq          bwghofaruydq  \
# 0                                     [Phone_number]        [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Person...  [Phone_number, Date]
# 2                                    +163 6 440 5217    (2804) 038 52 73 -
# 3                                   416.737.9285x710    (5575) 291 19 64 -
# 4                                       31 1792-0744    (2992) 707 68 30 -
#
#                                 mobilephonenumber.36  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                                 +92 (165) 75254-48
# 3                                         5329626342
# 4                                +55 (071) 3375-7834
#
#                                         usmvdyjshjrb  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Passpo...
# 2                                        18880977774
# 3                                      (342)392-8081
# 4                                         0279340988
#
#                                 cell_phone_number.20  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Passpo...
# 2                                      097 677-48-50
# 3                                         6120496814
# 4                                      +233567504076
#
#                                         phone_ext.23  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Phone_...
# 2                                       31 4374 3014
# 3                                        06415160231
# 4                                      +233579234929
#
#                                         itittmxlzqjr  \
# 0                                     [Phone_number]
# 1  [GPE, Geolocation, Other_data, Address, Passpo...
# 2                                   334-314-6849x206
# 3                             9652281017, 5500582145
# 4                                         1350292495
#
#                                     customer/contact
# 0                             [Person, Phone_number]
# 1  [GPE, Geolocation, Organization, Other_data, A...
# 2                              Mae/ +44(0)1514960632
# 3                         Kenlee/ +44(0)113 496 0895
# 4                  Roisin Harlow Archer/ 01 883 1767
#
# [5 rows x 4376 columns]

# %% [markdown]
# Presidio may needs a + or spaces to detect phone numbers

# %% [markdown]
# It is very difficult to compare Presidio with CASSED as CASSED has classes like Sexuality which Presidio can't detect

# %%
pd.DataFrame(wrong_columns).to_csv("dessi_cleaned/wrong_columns.csv", index=False)
dessi_labels_cleaned.to_csv("dessi_cleaned/all_labels_cleaned.csv", index=False)

# %% [markdown]
# Continuation in 'find_label_errors_3.ipynb'
